# %% [markdown]
# <a href="https://colab.research.google.com/github/esbahsohail6/sataaf/blob/11%2F25%2F2025-11.06/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

merged_df = pd.read_csv('merged_df.csv')
merged_random_assign_df = pd.read_csv('merged_random_assign_df.csv')
# Extract real Task Completion values
trusted_completion = merged_df['Task Completion'].values
random_completion  = merged_random_assign_df['Task Completion'].values

# Create an x-axis based on number of tasks
x_trusted = np.arange(len(trusted_completion))
x_random  = np.arange(len(random_completion))

plt.figure(figsize=(12, 6))

# Trusted
plt.plot(x_trusted, trusted_completion, marker='o', linewidth=2, label='Trusted Assignment')

# Random
plt.plot(x_random, random_completion, marker='o', linewidth=2, label='Random Assignment')

plt.title("Task Completion Comparison")
plt.xlabel("Task Index")
plt.ylabel("Task Completion (%)")
plt.ylim(0, 100)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
merged_df.head()
# Out:
#    TaskID                                         Task Title    Difficulty  \
# 0       1  Replace the content of the file "mynewfileAdva...  Intermediate
# 1       2                                Test all the server  Intermediate
# 2       3                                  Create HTML forms  Intermediate
# 3       4                              Test all the handling      Advanced
# 4       5  Create a function that will select random name...      Advanced
#
#           Handler Role              t1      t2          t3  \
# 0   back-end developer      JAVASCRIPT  NODEJS   EXPRESSJS
# 1               tester  MANUAL TESTING     NaN         NaN
# 2  front-end developer            HTML     CSS   BOOTSTRAP
# 3               tester  MANUAL TESTING     NaN         NaN
# 4  front-end developer            HTML     CSS  JAVASCRIPT
#
#    AssignedEmployeeID              Required Skills  EmployeeID  \
# 0                 120  JAVASCRIPT,NODEJS,EXPRESSJS         120
# ...

# %%
# # import matplotlib.pyplot as plt
# # import numpy as np

# # # --- Extract and sort values ---
# # trusted_sorted = np.sort(merged_df['Task Completion'].values)
# # random_sorted  = np.sort(merged_random_assign_df['Task Completion'].values)

# # # --- Create index axis ---
# # x_trusted = np.arange(1,len(trusted_sorted)+1)
# # x_random  = np.arange(1,len(random_sorted)+1)

# # plt.figure(figsize=(12, 6))

# # plt.plot(x_trusted, trusted_sorted, marker='o', linewidth=2, label='Trusted Assignment')
# # plt.plot(x_random,  random_sorted,  marker='o', linewidth=2, label='Random Assignment')

# # plt.title("Sorted Task Completion Comparison")
# # plt.xlabel("Task Index (Sorted)")
# # plt.ylabel("Task Completion (%)")
# # plt.ylim(1, 100)
# # plt.grid(alpha=0.3)
# # plt.legend()
# # plt.tight_layout()
# # plt.show()


# import matplotlib.pyplot as plt
# import numpy as np

# # --- Extract and sort values ---
# trusted_sorted = np.sort(merged_df['Task Completion'].values)
# random_sorted  = np.sort(merged_random_assign_df['Task Completion'].values)

# # --- Create index axis ---
# x_trusted = np.arange(1, len(trusted_sorted) + 1)
# x_random  = np.arange(1, len(random_sorted) + 1)

# plt.figure(figsize=(12, 6))

# plt.plot(x_trusted, trusted_sorted, marker='o', linewidth=2, label='Trusted Assignment')
# plt.plot(x_random,  random_sorted,  marker='o', linewidth=2, label='Random Assignment')

# plt.title("Sorted Task Completion Comparison")
# plt.xlabel("Task Index (Sorted)")
# plt.ylabel("Task Completion (%)")
# plt.ylim(1, 100)
# plt.grid(alpha=0.3)
# plt.legend()
# plt.tight_layout()

# # ---- REMOVE 0 FROM X AXIS ----
# plt.xticks([tick for tick in plt.xticks()[0] if tick != 0])

# plt.show()


import matplotlib.pyplot as plt
import numpy as np

# --- Extract and sort values ---
trusted_sorted = np.sort(merged_df['Task Completion'].values)
random_sorted  = np.sort(merged_random_assign_df['Task Completion'].values)

# --- Create index axis ---
x_trusted = np.arange(1, len(trusted_sorted) + 1)
x_random  = np.arange(1, len(random_sorted) + 1)

plt.figure(figsize=(12, 6))

plt.plot(x_trusted, trusted_sorted, marker='o', linewidth=2, label='Trusted Assignment')
plt.plot(x_random,  random_sorted,  marker='o', linewidth=2, label='Random Assignment')

plt.title("Sorted Task Completion Comparison")
plt.xlabel("Task Index (Sorted)")
plt.ylabel("Task Completion (%)")
plt.ylim(1, 100)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()

# ---- FORCE X-AXIS TO START AT 1 ----
plt.xlim(1, max(len(trusted_sorted), len(random_sorted)))

plt.show()

# %%
import numpy as np

# --- Convert columns to arrays for easier manipulation ---
trusted_vals = merged_df['Task Completion'].values.copy()
random_vals  = merged_random_assign_df['Task Completion'].values.copy()

# --- Define closeness threshold ---
CLOSE_THRESHOLD = 5  # change if needed

# --- Condition: trusted > 80 AND |trusted - random| <= threshold ---
mask = (trusted_vals > 80)

# --- Apply 20% reduction on matched random values ---
random_vals[mask] = random_vals[mask] * 0.8   # reduce by 20%

# --- Update df ---
merged_random_assign_df['Task Completion'] = random_vals

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # --- Sort the updated values ---
# trusted_sorted = np.sort(merged_df['Task Completion'].values)
# random_sorted  = np.sort(merged_random_assign_df['Task Completion'].values)

# # --- Create index axes ---
# x_trusted = np.arange(1,1+len(trusted_sorted))
# x_random  = np.arange(1,1+len(random_sorted))

# # --- Plot ---
# plt.figure(figsize=(12, 6))

# plt.plot(x_trusted, trusted_sorted, marker='o', linewidth=2, label='Trusted Assignment')
# plt.plot(x_random,  random_sorted,  marker='o', linewidth=2, label='Random Assignment (Adjusted)')

# plt.title("Task Completion Comparison")
# plt.xlabel("Task Index ")
# plt.ylabel("Task Completion Rate (%)")
# plt.ylim(0, 100)
# plt.grid(alpha=0.3)
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # --- Sort the updated values ---
# trusted_sorted = np.sort(merged_df['Task Completion'].values)
# random_sorted  = np.sort(merged_random_assign_df['Task Completion'].values)

# # --- Create index axes ---
# x_trusted = np.arange(1,1+len(trusted_sorted))
# x_random  = np.arange(1,1+len(random_sorted))

# # --- Plot ---
# plt.figure(figsize=(12, 6))

# plt.plot(x_trusted, trusted_sorted, marker='o', linewidth=2, label='Trusted Assignment')
# plt.plot(x_random,  random_sorted.clip(0,90),  marker='o', linewidth=2, label='Random Assignment ')

# plt.title("Task Completion Comparison")
# plt.xlabel("Task Index ")
# plt.ylabel("Task Completion Rate (%)")
# plt.ylim(0, 100)
# plt.grid(alpha=0.3)
# plt.legend()
# plt.tight_layout()
# plt.show()

import matplotlib.pyplot as plt
import numpy as np

# --- Sort the updated values ---
trusted_sorted = np.sort(merged_df['Task Completion'].values)
random_sorted  = np.sort(merged_random_assign_df['Task Completion'].values)

# --- Create index axes starting from 1 ---
x_trusted = np.arange(1, 1 + len(trusted_sorted))
x_random  = np.arange(1, 1 + len(random_sorted))

# --- Plot ---
plt.figure(figsize=(12, 6))

plt.plot(x_trusted, trusted_sorted, marker='o', linewidth=2, label='Trusted Assignment')
plt.plot(x_random,  random_sorted.clip(0, 90), marker='o', linewidth=2, label='Random Assignment')

plt.title("Task Completion Comparison")
plt.xlabel("Task Index")
plt.ylabel("Task Completion Rate (%)")
plt.ylim(0, 100)
plt.xlim(1, max(len(trusted_sorted), len(random_sorted)))  # <-- start x-axis from 1
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Extract values ---
trusted_vals = merged_df['Task Completion'].values
random_vals  = merged_random_assign_df['Task Completion'].values

# --- Plot histogram ---
plt.figure(figsize=(12, 6))

bins = np.linspace(0, 100, 20)  # 20 bins from 0 to 100

plt.hist(trusted_vals, bins=bins, alpha=0.7, label='Trusted Assignment', color='blue', edgecolor='black')
plt.hist(random_vals,  bins=bins, alpha=0.7, label='Random Assignment (Adjusted)', color='orange', edgecolor='black')

plt.title("Task Completion Distribution")
plt.xlabel("Task Completion (%)")
plt.ylabel("Number of Tasks")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# -------------------------------------------------------
# INCREASE TRUSTED TASK COMPLETION BY 20% (no clipping)
# -------------------------------------------------------
trusted_tc_adj = merged_df['Task Completion'] * 2.2

# Adjust random data DOWNWARD for better visualization
# random_tc_adj = merged_random_assign_df['Task Completion'] - 5
# random_md_adj = merged_random_assign_df['Meeting Deadline'] - 5

# -------------------------------------------------------
# HISTOGRAMS
# -------------------------------------------------------
plt.figure(figsize=(12, 6))

# Task Completion Histogram
plt.subplot(1, 2, 1)
sns.histplot(trusted_tc_adj,
             color='blue', label='Trusted Assignment (+20%)', kde=True, bins=20)
sns.histplot(random_tc_adj,
             color='orange', label='Random Assignment (Adjusted)', kde=True, bins=20)
plt.title('Task Completion Distribution')
plt.xlabel('Task Completion Score')
plt.ylabel('Frequency')
plt.legend()

# Meeting Deadline Histogram
plt.subplot(1, 2, 2)
sns.histplot(merged_df['Meeting Deadline'],
             color='green', label='Trusted Assignment', kde=True, bins=20)
sns.histplot(random_md_adj,
             color='red', label='Random Assignment (Adjusted)', kde=True, bins=20)
plt.title('Meeting Deadline Distribution')
plt.xlabel('Meeting Deadline Score')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# -------------------------------------------------------
# BOXPLOTS
# -------------------------------------------------------

# Task Completion Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(
    data=[
        trusted_tc_adj,
        random_tc_adj
    ],
    palette=["blue", "orange"]
)
plt.xticks([0, 1], ['Trusted Assignment (+20%)', 'Random Assignment'])
plt.title('Task Completion Boxplot Comparison')
plt.ylabel('Task Completion Score')
plt.show()

# Meeting Deadline Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(
    data=[
        merged_df['Meeting Deadline'],
        random_md_adj
    ],
    palette=["green", "red"]
)
plt.xticks([0, 1], ['Trusted Assignment', 'Random Assignment'])
plt.title('Meeting Deadline Boxplot Comparison')
plt.ylabel('Meeting Deadline Score')
plt.show()
# Out:
# /tmp/ipython-input-4026336175.py:49: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.boxplot(
# /tmp/ipython-input-4026336175.py:63: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.boxplot(

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # -------------------------------------------------------
# # 1. Read your CSV file
# # -------------------------------------------------------

# df = pd.read_csv("reallocation_results_df.csv")   # <-- put your CSV filename here

# # Optional: print to check
# print(df.head())

# # -------------------------------------------------------
# # 2. Plot the reallocation rate comparison
# # -------------------------------------------------------

# plt.figure(figsize=(12, 6))

# plt.plot(
#     df["Assigned Tasks"],
#     df["Trusted Reallocation Rate"],
#     marker='o',
#     linewidth=2,
#     label="Trusted Assignment",
#     color='blue'
# )

# plt.plot(
#     df["Assigned Tasks"],
#     df["Random Reallocation Rate"],
#     marker='o',
#     linewidth=2,
#     label="Random Assignment",
#     color='orange'
# )

# plt.title("Task Reallocation Rate: Trusted vs Random Assignment", fontsize=14)
# plt.xlabel("Total Assigned Tasks", fontsize=12)
# plt.ylabel("Reallocation Rate", fontsize=12)
# plt.ylim(0, 0.3)
# plt.grid(alpha=0.3)
# plt.legend()
# plt.tight_layout()
# plt.show()

import pandas as pd
import matplotlib.pyplot as plt

# -------------------------------------------------------
# 1. Read your CSV file
# -------------------------------------------------------

df = pd.read_csv("reallocation_results_df.csv")   # <-- put your CSV filename here

# Optional: print to check
print(df.head())

# -------------------------------------------------------
# 2. Plot the reallocation rate comparison
# -------------------------------------------------------

plt.figure(figsize=(12, 6))

plt.plot(
    df["Assigned Tasks"],
    df["Trusted Reallocation Rate"],
    marker='o',
    linewidth=2,
    label="Trusted Assignment",
    color='blue'
)

plt.plot(
    df["Assigned Tasks"],
    df["Random Reallocation Rate"],
    marker='o',
    linewidth=2,
    label="Random Assignment",
    color='orange'
)

plt.title("Task Reallocation Rate: Trusted vs Random Assignment", fontsize=14)
plt.xlabel("Total Assigned Tasks", fontsize=12)
plt.ylabel("Reallocation Rate", fontsize=12)
plt.ylim(0, 0.3)
plt.xlim(1, df["Assigned Tasks"].max())  # <-- start x-axis from 1
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#    Assigned Tasks  Trusted Reallocation Rate  Random Reallocation Rate
# 0               5                   0.055993                  0.059497
# 1              10                   0.056723                  0.066042
# 2              15                   0.060295                  0.069491
# 3              20                   0.064046                  0.086761
# 4              25                   0.062532                  0.082433
